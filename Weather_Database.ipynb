# %% [markdown]
# # Challenge Part 1

# %%
# Get the Weather Description and Amount of Precipitation for Each City

# %%
# %matplotlib inline

# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os 
import statistics
import scipy.stats as sts
# Import mpl to change the plot configurations using rcParams.
import matplotlib as mpl

import random 
import timeit
import requests
import time
import gmaps

#Notice the difference in import syntax for these modules. This eliminates the need to double type the name
#For example: datetime.datetime.xyz
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress

# Import API keys.
from config import weather_api_key

from config import g_key
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Part 1 section 2 ####################################################################################
#Create a new list of 1,500 Latitude and Longitude pairs


# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

#The zip helps with memory management. It creates an iterable object. After you iterate over it, the zip empties.
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Part 1 section 3 ####################################################################################
# Add the latitudes and longitudes to a list. 

coordinates = list(lat_lngs)

#Now that we have our ordered pairs of latitudes and longitudes in a list, 
#we can iterate through the list of tuples and find the nearest city to those coordinates.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 614

# %%
# Part 1 section 4 & 5 ####################################################################################
# Get the City Weather Data from OpenWeatherMap 

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
# Enumerate allows access to the index
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        try:
            city_weatherDescription = str(city_weather["weather"]["description"])
            print(city_weatherDescription)
        except:
            city_weatherDescription = "descriptionexception"
            pass
            
        try:
            city_rainfall_lastHour = city_weather["rain"]["1h"]
        except:
            city_rainfall_lastHour = 0
            pass

        try:
            city_snowfall_lastHour = city_weather["snow"]["1h"]
        except:
            city_snowfall_lastHour = 0
            pass

        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_weatherDescription,
                          "Rain last hr":city_rainfall_lastHour,
                          "Snow last hr":city_snowfall_lastHour})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cruz alta
# Processing Record 2 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | mehamn
# Processing Record 9 of Set 1 | havre
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | ixtapa
# Processing Record 12 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | tanhacu
# Processing Record 16 of Set 1 | coquimbo
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | arlit
# Processing Record 19 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | port shepstone
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | manavalakurichi
# Processing Record 34 of Set 1 | hervey bay
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | buala
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | lazaro cardenas
# Processing Record 40 of Set 1 | liepaja
# Processing Record 41 of Set 1 | sosua
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | la ronge
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | dongying
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | gravdal
# Processing Record 50 of Set 1 | ojinaga
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | xianshuigu
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | buritis
# Processing Record 5 of Set 2 | chabahar
# Processing Record 6 of Set 2 | wamba
# Processing Record 7 of Set 2 | san vicente
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | mahibadhoo
# Processing Record 10 of Set 2 | new glasgow
# Processing Record 11 of Set 2 | mizdah
# Processing Record 12 of Set 2 | vila
# Processing Record 13 of Set 2 | betsiamites
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | pemangkat
# Processing Record 16 of Set 2 | nome
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | pryluky
# Processing Record 19 of Set 2 | san andres
# Processing Record 20 of Set 2 | novyy urengoy
# Processing Record 21 of Set 2 | alto araguaia
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | inverness
# Processing Record 25 of Set 2 | borogontsy
# Processing Record 26 of Set 2 | rio grande
# Processing Record 27 of Set 2 | nushki
# Processing Record 28 of Set 2 | baherden
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | alice springs
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | abreus
# Processing Record 33 of Set 2 | aleksandrov gay
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | oranjemund
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | nicolas bravo
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | soimi
# Processing Record 43 of Set 2 | atambua
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | swabi
# Processing Record 46 of Set 2 | zhigansk
# Processing Record 47 of Set 2 | kokoda
# Processing Record 48 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 2 | shingu
# Processing Record 50 of Set 2 | komsomolskiy
# Processing Record 1 of Set 3 | azul
# Processing Record 2 of Set 3 | lagunas
# Processing Record 3 of Set 3 | tura
# Processing Record 4 of Set 3 | talnakh
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | ponta delgada
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | lima
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | constantine
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | bonavista
# Processing Record 19 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 20 of Set 3 | barcelos
# Processing Record 21 of Set 3 | pastavy
# Processing Record 22 of Set 3 | usinsk
# Processing Record 23 of Set 3 | acutzilapan
# City not found. Skipping...
# Processing Record 24 of Set 3 | palembang
# Processing Record 25 of Set 3 | tacoronte
# Processing Record 26 of Set 3 | turukhansk
# Processing Record 27 of Set 3 | talcahuano
# Processing Record 28 of Set 3 | mareeba
# Processing Record 29 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 30 of Set 3 | esso
# Processing Record 31 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 3 | mayo
# Processing Record 33 of Set 3 | brookhaven
# Processing Record 34 of Set 3 | alofi
# Processing Record 35 of Set 3 | kununurra
# Processing Record 36 of Set 3 | otane
# Processing Record 37 of Set 3 | grand gaube
# Processing Record 38 of Set 3 | ashington
# Processing Record 39 of Set 3 | carutapera
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | eenhana
# Processing Record 42 of Set 3 | kattivakkam
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | batagay-alyta
# Processing Record 45 of Set 3 | serenje
# Processing Record 46 of Set 3 | manokwari
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | carbunari
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | bilma
# Processing Record 4 of Set 4 | finnsnes
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | along
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | labuhan
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | ati
# Processing Record 13 of Set 4 | zhukovka
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | clyde river
# Processing Record 16 of Set 4 | walvis bay
# Processing Record 17 of Set 4 | chadiza
# Processing Record 18 of Set 4 | grand-santi
# Processing Record 19 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 4 | santiago tuxtla
# Processing Record 21 of Set 4 | lagoa
# Processing Record 22 of Set 4 | chuy
# Processing Record 23 of Set 4 | cascais
# Processing Record 24 of Set 4 | vostok
# Processing Record 25 of Set 4 | atuona
# Processing Record 26 of Set 4 | tocopilla
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | migori
# Processing Record 29 of Set 4 | sterling
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | sokoni
# Processing Record 36 of Set 4 | strenci
# Processing Record 37 of Set 4 | nemuro
# Processing Record 38 of Set 4 | jardim
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | sawtell
# Processing Record 41 of Set 4 | zalantun
# Processing Record 42 of Set 4 | nabire
# Processing Record 43 of Set 4 | tanout
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | koslan
# Processing Record 46 of Set 4 | okhotsk
# Processing Record 47 of Set 4 | hilo
# Processing Record 48 of Set 4 | anchorage
# Processing Record 49 of Set 4 | nelson bay
# Processing Record 50 of Set 4 | roma
# Processing Record 1 of Set 5 | pangai
# Processing Record 2 of Set 5 | northam
# Processing Record 3 of Set 5 | miri
# Processing Record 4 of Set 5 | chumikan
# Processing Record 5 of Set 5 | dwarka
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | ulaanbaatar
# Processing Record 8 of Set 5 | zhanaozen
# Processing Record 9 of Set 5 | qaqortoq
# Processing Record 10 of Set 5 | pershotravneve
# Processing Record 11 of Set 5 | chateauroux
# Processing Record 12 of Set 5 | coos bay
# Processing Record 13 of Set 5 | castro
# Processing Record 14 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 5 | dudinka
# Processing Record 19 of Set 5 | severo-kurilsk
# Processing Record 20 of Set 5 | sergeyevka
# Processing Record 21 of Set 5 | tautira
# Processing Record 22 of Set 5 | los reyes
# Processing Record 23 of Set 5 | chokurdakh
# Processing Record 24 of Set 5 | orlik
# Processing Record 25 of Set 5 | shellbrook
# Processing Record 26 of Set 5 | ingraj bazar
# Processing Record 27 of Set 5 | novoorsk
# Processing Record 28 of Set 5 | myitkyina
# Processing Record 29 of Set 5 | waipawa
# Processing Record 30 of Set 5 | mnogovershinnyy
# Processing Record 31 of Set 5 | almaznyy
# Processing Record 32 of Set 5 | tecoanapa
# Processing Record 33 of Set 5 | mana
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | roros
# Processing Record 36 of Set 5 | the valley
# Processing Record 37 of Set 5 | dennery
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | opuwo
# Processing Record 40 of Set 5 | xiamen
# Processing Record 41 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 42 of Set 5 | karratha
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | nieuw amsterdam
# Processing Record 45 of Set 5 | paungde
# Processing Record 46 of Set 5 | thompson
# Processing Record 47 of Set 5 | camacha
# Processing Record 48 of Set 5 | ureki
# Processing Record 49 of Set 5 | cedar city
# Processing Record 50 of Set 5 | tambilil
# Processing Record 1 of Set 6 | trairi
# Processing Record 2 of Set 6 | saint-pierre
# Processing Record 3 of Set 6 | richards bay
# Processing Record 4 of Set 6 | alyangula
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 6 | teul
# City not found. Skipping...
# Processing Record 8 of Set 6 | champerico
# Processing Record 9 of Set 6 | byron bay
# Processing Record 10 of Set 6 | sao joao da barra
# Processing Record 11 of Set 6 | sulphur springs
# Processing Record 12 of Set 6 | ust-ilimsk
# Processing Record 13 of Set 6 | srednekolymsk
# Processing Record 14 of Set 6 | biak
# Processing Record 15 of Set 6 | waingapu
# Processing Record 16 of Set 6 | praia da vitoria
# Processing Record 17 of Set 6 | copiapo
# Processing Record 18 of Set 6 | mar del plata
# Processing Record 19 of Set 6 | tomatlan
# Processing Record 20 of Set 6 | vigevano
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 6 | mapiripan
# Processing Record 24 of Set 6 | cocobeach
# Processing Record 25 of Set 6 | araouane
# Processing Record 26 of Set 6 | meulaboh
# Processing Record 27 of Set 6 | elizabeth city
# Processing Record 28 of Set 6 | ahuimanu
# Processing Record 29 of Set 6 | le vauclin
# Processing Record 30 of Set 6 | kargasok
# Processing Record 31 of Set 6 | santa ana
# Processing Record 32 of Set 6 | emerald
# Processing Record 33 of Set 6 | te anau
# Processing Record 34 of Set 6 | ancud
# Processing Record 35 of Set 6 | brownsburg
# Processing Record 36 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | wanaka
# Processing Record 38 of Set 6 | rundu
# Processing Record 39 of Set 6 | camana
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | shenjiamen
# Processing Record 42 of Set 6 | atar
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 6 | morro bay
# Processing Record 48 of Set 6 | aripuana
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | bandundu
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | katsina
# Processing Record 3 of Set 7 | saint-joseph
# Processing Record 4 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 7 | deputatskiy
# Processing Record 6 of Set 7 | sao gabriel da cachoeira
# Processing Record 7 of Set 7 | makakilo city
# Processing Record 8 of Set 7 | halifax
# Processing Record 9 of Set 7 | sistranda
# Processing Record 10 of Set 7 | dicabisagan
# Processing Record 11 of Set 7 | fairbanks
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | ballitoville
# Processing Record 14 of Set 7 | dubinino
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | tabuk
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | batticaloa
# Processing Record 19 of Set 7 | tessalit
# Processing Record 20 of Set 7 | terrace
# Processing Record 21 of Set 7 | tarauaca
# Processing Record 22 of Set 7 | malakal
# Processing Record 23 of Set 7 | mahon
# Processing Record 24 of Set 7 | chimore
# Processing Record 25 of Set 7 | haines junction
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | pathein
# Processing Record 31 of Set 7 | constitucion
# Processing Record 32 of Set 7 | yar-sale
# Processing Record 33 of Set 7 | gayny
# Processing Record 34 of Set 7 | keti bandar
# Processing Record 35 of Set 7 | kidal
# Processing Record 36 of Set 7 | aguas formosas
# Processing Record 37 of Set 7 | tianpeng
# Processing Record 38 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 39 of Set 7 | goya
# Processing Record 40 of Set 7 | kyren
# Processing Record 41 of Set 7 | sitka
# Processing Record 42 of Set 7 | poronaysk
# Processing Record 43 of Set 7 | progreso
# Processing Record 44 of Set 7 | cuamba
# Processing Record 45 of Set 7 | torbay
# Processing Record 46 of Set 7 | mazyr
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | ilhabela
# Processing Record 49 of Set 7 | north bend
# Processing Record 50 of Set 7 | henties bay
# Processing Record 1 of Set 8 | saint-georges
# Processing Record 2 of Set 8 | biankouma
# Processing Record 3 of Set 8 | havre-saint-pierre
# Processing Record 4 of Set 8 | vila velha
# Processing Record 5 of Set 8 | seoul
# Processing Record 6 of Set 8 | vila praia de ancora
# Processing Record 7 of Set 8 | nieuwpoort
# Processing Record 8 of Set 8 | manggar
# Processing Record 9 of Set 8 | pinotepa nacional
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | coihaique
# Processing Record 12 of Set 8 | gat
# Processing Record 13 of Set 8 | karacabey
# Processing Record 14 of Set 8 | nouadhibou
# Processing Record 15 of Set 8 | kavaratti
# Processing Record 16 of Set 8 | pacific grove
# Processing Record 17 of Set 8 | berlevag
# Processing Record 18 of Set 8 | hibbing
# Processing Record 19 of Set 8 | brae
# Processing Record 20 of Set 8 | moroni
# Processing Record 21 of Set 8 | aginskoye
# Processing Record 22 of Set 8 | tommot
# Processing Record 23 of Set 8 | bosaso
# Processing Record 24 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 8 | okha
# Processing Record 27 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 8 | boone
# Processing Record 29 of Set 8 | mao
# Processing Record 30 of Set 8 | iralaya
# Processing Record 31 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 32 of Set 8 | shache
# Processing Record 33 of Set 8 | cabo san lucas
# Processing Record 34 of Set 8 | zhangye
# Processing Record 35 of Set 8 | beringovskiy
# Processing Record 36 of Set 8 | airai
# Processing Record 37 of Set 8 | saint-cesaire
# Processing Record 38 of Set 8 | sept-iles
# Processing Record 39 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 8 | muros
# Processing Record 41 of Set 8 | ust-kuyga
# Processing Record 42 of Set 8 | the pas
# Processing Record 43 of Set 8 | kamarion
# Processing Record 44 of Set 8 | tiznit
# Processing Record 45 of Set 8 | ahar
# Processing Record 46 of Set 8 | san quintin
# Processing Record 47 of Set 8 | bonthe
# Processing Record 48 of Set 8 | dogondoutchi
# Processing Record 49 of Set 8 | hope
# Processing Record 50 of Set 8 | virginia beach
# Processing Record 1 of Set 9 | mackay
# Processing Record 2 of Set 9 | cap malheureux
# Processing Record 3 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | wunsiedel
# Processing Record 6 of Set 9 | nadvoitsy
# Processing Record 7 of Set 9 | husavik
# Processing Record 8 of Set 9 | bahir dar
# Processing Record 9 of Set 9 | abakaliki
# Processing Record 10 of Set 9 | acapulco
# Processing Record 11 of Set 9 | bom jesus da lapa
# Processing Record 12 of Set 9 | jaisinghnagar
# Processing Record 13 of Set 9 | opportunity
# Processing Record 14 of Set 9 | mount isa
# Processing Record 15 of Set 9 | ouadda
# Processing Record 16 of Set 9 | fare
# Processing Record 17 of Set 9 | yershov
# Processing Record 18 of Set 9 | yellowknife
# Processing Record 19 of Set 9 | kutum
# Processing Record 20 of Set 9 | esna
# Processing Record 21 of Set 9 | fairlie
# Processing Record 22 of Set 9 | ambilobe
# Processing Record 23 of Set 9 | margate
# Processing Record 24 of Set 9 | andenes
# Processing Record 25 of Set 9 | cockburn town
# Processing Record 26 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 9 | hami
# Processing Record 28 of Set 9 | lensk
# Processing Record 29 of Set 9 | belyy yar
# Processing Record 30 of Set 9 | noumea
# Processing Record 31 of Set 9 | saskylakh
# Processing Record 32 of Set 9 | alibag
# Processing Record 33 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 9 | kloulklubed
# Processing Record 35 of Set 9 | pizarro
# Processing Record 36 of Set 9 | gornoye loo
# Processing Record 37 of Set 9 | coolum beach
# Processing Record 38 of Set 9 | ostrovnoy
# Processing Record 39 of Set 9 | tokur
# Processing Record 40 of Set 9 | iwanai
# Processing Record 41 of Set 9 | shizunai
# Processing Record 42 of Set 9 | khash
# Processing Record 43 of Set 9 | lumsden
# Processing Record 44 of Set 9 | chardara
# Processing Record 45 of Set 9 | krasnoselkup
# Processing Record 46 of Set 9 | flinders
# Processing Record 47 of Set 9 | pangnirtung
# Processing Record 48 of Set 9 | leshukonskoye
# Processing Record 49 of Set 9 | tarumovka
# Processing Record 50 of Set 9 | inuvik
# Processing Record 1 of Set 10 | ocos
# Processing Record 2 of Set 10 | vardo
# Processing Record 3 of Set 10 | bocas del toro
# Processing Record 4 of Set 10 | kijang
# Processing Record 5 of Set 10 | avera
# Processing Record 6 of Set 10 | bulgan
# Processing Record 7 of Set 10 | aflao
# Processing Record 8 of Set 10 | axim
# Processing Record 9 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 10 | neuquen
# Processing Record 11 of Set 10 | sao joao
# Processing Record 12 of Set 10 | ewo
# Processing Record 13 of Set 10 | adrar
# Processing Record 14 of Set 10 | mount pleasant
# Processing Record 15 of Set 10 | charters towers
# Processing Record 16 of Set 10 | bengkulu
# Processing Record 17 of Set 10 | adand
# Processing Record 18 of Set 10 | lerwick
# Processing Record 19 of Set 10 | sur
# Processing Record 20 of Set 10 | kirakira
# Processing Record 21 of Set 10 | vaasa
# Processing Record 22 of Set 10 | ulladulla
# Processing Record 23 of Set 10 | vagur
# Processing Record 24 of Set 10 | gresham
# Processing Record 25 of Set 10 | swindon
# Processing Record 26 of Set 10 | price
# Processing Record 27 of Set 10 | krasnokamensk
# Processing Record 28 of Set 10 | half moon bay
# Processing Record 29 of Set 10 | panji
# Processing Record 30 of Set 10 | mantua
# Processing Record 31 of Set 10 | kruisfontein
# Processing Record 32 of Set 10 | palmer
# Processing Record 33 of Set 10 | jega
# Processing Record 34 of Set 10 | mercedes
# Processing Record 35 of Set 10 | haverfordwest
# Processing Record 36 of Set 10 | posse
# Processing Record 37 of Set 10 | schongau
# Processing Record 38 of Set 10 | takoradi
# Processing Record 39 of Set 10 | bilibino
# Processing Record 40 of Set 10 | antofagasta
# Processing Record 41 of Set 10 | pafos
# Processing Record 42 of Set 10 | vadso
# Processing Record 43 of Set 10 | nagato
# Processing Record 44 of Set 10 | vuktyl
# Processing Record 45 of Set 10 | yeppoon
# Processing Record 46 of Set 10 | zhanakorgan
# Processing Record 47 of Set 10 | sakakah
# Processing Record 48 of Set 10 | umm lajj
# Processing Record 49 of Set 10 | harper
# Processing Record 50 of Set 10 | korgen
# Processing Record 1 of Set 11 | kameshkovo
# Processing Record 2 of Set 11 | castrillon
# Processing Record 3 of Set 11 | tilichiki
# Processing Record 4 of Set 11 | misratah
# Processing Record 5 of Set 11 | vao
# Processing Record 6 of Set 11 | alugan
# Processing Record 7 of Set 11 | kichmengskiy gorodok
# Processing Record 8 of Set 11 | baykit
# Processing Record 9 of Set 11 | diamantino
# Processing Record 10 of Set 11 | uglovskoye
# Processing Record 11 of Set 11 | shebalino
# Processing Record 12 of Set 11 | tarazona
# Processing Record 13 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 11 | barra do corda
# Processing Record 15 of Set 11 | plettenberg bay
# Processing Record 16 of Set 11 | mitchell
# Processing Record 17 of Set 11 | pitimbu
# Processing Record 18 of Set 11 | santa maria
# Processing Record 19 of Set 11 | itarema
# Processing Record 20 of Set 11 | thabazimbi
# Processing Record 21 of Set 11 | kenora
# Processing Record 22 of Set 11 | salinopolis
# Processing Record 23 of Set 11 | klyuchi
# Processing Record 24 of Set 11 | samarai
# Processing Record 25 of Set 11 | ajdabiya
# Processing Record 26 of Set 11 | aurora
# Processing Record 27 of Set 11 | celestun
# Processing Record 28 of Set 11 | ialibu
# Processing Record 29 of Set 11 | egvekinot
# Processing Record 30 of Set 11 | la reforma
# Processing Record 31 of Set 11 | nouna
# Processing Record 32 of Set 11 | cangzhou
# Processing Record 33 of Set 11 | kamenka
# Processing Record 34 of Set 11 | ambon
# Processing Record 35 of Set 11 | forio
# Processing Record 36 of Set 11 | mountain home
# Processing Record 37 of Set 11 | chortomlyk
# Processing Record 38 of Set 11 | ilulissat
# Processing Record 39 of Set 11 | tete
# Processing Record 40 of Set 11 | indramayu
# Processing Record 41 of Set 11 | north tonawanda
# Processing Record 42 of Set 11 | ust-karsk
# Processing Record 43 of Set 11 | tarko-sale
# Processing Record 44 of Set 11 | akhmeta
# Processing Record 45 of Set 11 | ko samui
# Processing Record 46 of Set 11 | gander
# Processing Record 47 of Set 11 | chase
# Processing Record 48 of Set 11 | namtsy
# Processing Record 49 of Set 11 | sehore
# Processing Record 50 of Set 11 | deniliquin
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | merauke
# Processing Record 3 of Set 12 | zyryanka
# Processing Record 4 of Set 12 | college
# Processing Record 5 of Set 12 | west wendover
# Processing Record 6 of Set 12 | shorapani
# Processing Record 7 of Set 12 | juneau
# Processing Record 8 of Set 12 | namatanai
# Processing Record 9 of Set 12 | osa
# Processing Record 10 of Set 12 | ushtobe
# Processing Record 11 of Set 12 | houma
# Processing Record 12 of Set 12 | aguas vermelhas
# Processing Record 13 of Set 12 | paita
# Processing Record 14 of Set 12 | hudiksvall
# Processing Record 15 of Set 12 | el alto
# Processing Record 16 of Set 12 | jalu
# Processing Record 17 of Set 12 | hualmay
# Processing Record 18 of Set 12 | portland
# Processing Record 19 of Set 12 | saint-louis
# Processing Record 20 of Set 12 | sainte-suzanne
# Processing Record 21 of Set 12 | xai-xai
# Processing Record 22 of Set 12 | rio bananal
# Processing Record 23 of Set 12 | belmonte
# Processing Record 24 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 12 | bowen
# Processing Record 26 of Set 12 | saint-augustin
# Processing Record 27 of Set 12 | dali
# Processing Record 28 of Set 12 | hailar
# Processing Record 29 of Set 12 | taoudenni
# Processing Record 30 of Set 12 | puerto del rosario
# Processing Record 31 of Set 12 | chaohu
# Processing Record 32 of Set 12 | narsaq
# Processing Record 33 of Set 12 | san lazaro
# Processing Record 34 of Set 12 | chipinge
# Processing Record 35 of Set 12 | pacifica
# Processing Record 36 of Set 12 | malanje
# Processing Record 37 of Set 12 | aras
# Processing Record 38 of Set 12 | asau
# Processing Record 39 of Set 12 | mosquera
# Processing Record 40 of Set 12 | el bagre
# Processing Record 41 of Set 12 | wukari
# Processing Record 42 of Set 12 | port moresby
# Processing Record 43 of Set 12 | boksitogorsk
# Processing Record 44 of Set 12 | medak
# Processing Record 45 of Set 12 | guozhen
# Processing Record 46 of Set 12 | khandagayty
# Processing Record 47 of Set 12 | puerto baquerizo moreno
# Processing Record 48 of Set 12 | karari
# Processing Record 49 of Set 12 | lahat
# Processing Record 50 of Set 12 | svetlogorsk
# Processing Record 1 of Set 13 | sao filipe
# Processing Record 2 of Set 13 | ngunguru
# Processing Record 3 of Set 13 | menongue
# Processing Record 4 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 13 | lashio
# Processing Record 6 of Set 13 | devils lake
# Processing Record 7 of Set 13 | ternate
# Processing Record 8 of Set 13 | naantali
# Processing Record 9 of Set 13 | taywarah
# Processing Record 10 of Set 13 | paamiut
# Processing Record 11 of Set 13 | hirara
# Processing Record 12 of Set 13 | chiang klang
# Processing Record 13 of Set 13 | puerto lempira
# Processing Record 14 of Set 13 | bermeo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 571

# %%
# Part 1 section 6 ####################################################################################
#convert the list to a Dataframe

#convert to Dataframe
city_date_df = pd.DataFrame(city_data)
city_date_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cruz Alta -28.64  -53.61     45.05        85          58
# 1            Hobart -42.88  147.33     39.99        93          20
# 2         Tuatapere -46.13  167.68     47.59        85         100
# 3              Lebu -37.62  -73.65     51.80        88         100
# 4          Tasiilaq  65.61  -37.64     42.80        87         100
# ..              ...    ...     ...       ...       ...         ...
# 566         Paamiut  61.99  -49.67     41.34        84          88
# 567          Hirara  24.80  125.28     86.00        94          75
# 568    Chiang Klang  19.29  100.86     77.00       100          40
# 569  Puerto Lempira  15.27  -83.77     77.00        88          90
# 570          Bermeo  43.42   -2.72     68.00        88          75
#
#      Wind Speed Country                 Date           Description  \
# 0         12.84      BR  2020-06-27 23:25:44  descriptionexception
# 1          9.17      AU  2020-06-27 23:25:44  descriptionexception
# 2          3.87      NZ  2020-06-27 23:25:44  descriptionexception
# 3         12.59      CL  2020-06-27 23:25:44  descriptionexception
# 4          1.12      GL  2020-06-27 23:25:44  descriptionexception
# ..          ...     ...                  ...                   ...
# 566        1.79      GL  2020-06-27 23:27:15  descriptionexception
# 567        8.05      JP  2020-06-27 23:27:15  descriptionexception
# 568        1.12      TH  2020-06-27 23:27:15  descriptionexception
# 569        6.98      HN  2020-06-27 23:27:15  descriptionexception
# 570        6.93      ES  2020-06-27 23:27:15  descriptionexception
#
#      Rain last hr  Snow last hr
# 0            0.00           0.0
# 1            0.00           0.0
# 2            0.00           0.0
# 3            0.69           0.0
# 4            0.00           0.0
# ..            ...           ...
# 566          0.00           0.0
# 567          0.00           0.0
# 568          0.00           0.0
# 569          0.00           0.0
# 570          0.00           0.0
#
# [571 rows x 12 columns]

# %%
# Part 1 section 7 ####################################################################################
#save Dataframe as CSV


city_date_df.to_csv("weather_data\WeatherPy_database.csv", index = True)

# %% [markdown]
# # Challenge Part 2
